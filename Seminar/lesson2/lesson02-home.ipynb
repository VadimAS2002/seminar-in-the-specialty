# %% [markdown]
# ## LESSON 02: FUNDAMENTALS OF ML AND STATISTICAL LEARNING

# %% [markdown]
# ### 1. Metadata
# Each file contains the following fields:
#
# club: Team abbreviation
# last_name: Player last name
# first_name: Player first name
# position: Position abbreviation
# base_salary: Base salary
# guaranteed_compensation: Guaranteed compensationentirely.

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
# Define the column names as a list
column_names = ['Player','Club','POS','GP','GS','MINS','G','A','SHTS','SOG','GWG','PKG/A','HmG','RdG','G/90min','SC%','GWA','HmA','RdA','A/90min',
                'FC','FS','OFF','YC','RC','SOG%','Year','Season']

# %% [markdown]
# ### 2. Load Dataset

# %%
dataset = pd.read_csv("dataset/all_players-home.data", names = column_names, sep = ",", skipinitialspace=True)
dataset.head()
# Out:
#             Player Club POS  GP  GS  MINS   G   A  SHTS  SOG  ...  RdA  \
# 0     Roy Lassiter  TB    F  30  30  2580  27   4    76   49  ...    2
# 1   Raul Diaz Arce  DC    F  28  28  2351  23   2   100   49  ...    2
# 2  Eduardo Hurtado  LA    F  26  26  2323  21   7    87   56  ...    3
# 3            Preki  KC    M  32  32  2880  18  13   140   61  ...    4
# 4    Brian McBride  CLB   F  28  28  2307  17   3    79   44  ...    1
#
#   A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season
# 0    0.14  20  39   70   2   0  64.47  1996     reg
# 1    0.08  32  26   35   6   1  49.00  1996     reg
# 2    0.27  48  26   25   5   0  64.37  1996     reg
# 3    0.41  26  44    7   3   0  43.57  1996     reg
# 4    0.12  21  46   10   0   0  55.70  1996     reg
#
# [5 rows x 28 columns]

# %%
# print important information about dataset
print("#Total of samples = ", dataset.shape[0])
print("#Features = ", dataset.shape[1])
# Out:
# #Total of samples =  15767
# #Features =  28

# %%
# checking the missing values
dataset[dataset.eq("?").any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Player, Club, POS, GP, GS, MINS, G, A, SHTS, SOG, GWG, PKG/A, HmG, RdG, G/90min, SC%, GWA, HmA, RdA, A/90min, FC, FS, OFF, YC, RC, SOG%, Year, Season]
# Index: []
#
# [0 rows x 28 columns]

# %%
# replace data with '?' by NaN
dataset.replace("?", np.nan, inplace=True)
dataset[dataset.isna().any(axis=1)].head()
print("#Samples with missing values = ", len(dataset[dataset.isna().any(axis=1)]))
# Out:
# #Samples with missing values =  7529

# %% [markdown]
# Filtering missing values

# %%
# plot missing data
sbn.displot(
    data = dataset.isna().melt(value_name="missing"),
    y = "variable",
    hue = "missing",
    multiple = "fill",
    aspect = 1.5
)

plt.show()
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dataset = dataset.dropna()
print("#Total samples without missing values = ", len(dataset))
# Out:
# #Total samples without missing values =  8238

# %% [markdown]
# ### 3. Descriptive Statistical Analysis

# %% [markdown]
# #### Numerical variables

# %%
# list of numerical variables 
numerical_cols = ['GP','GS','MINS','G','A','SHTS','SOG','GWG']

# %% [markdown]
# Histogram with Frequencies

# %%
# function to plot distribution for 1 numerical column
def hist_frequencies(data, column, bins):
    sbn.histplot(data[column], color = "blue", bins = bins)
    plt.xlabel(column)
    plt.ylabel("Frequencies")
    plt.title("Histogram distribution for " + column)    
    plt.show()

# %%
# plot the distribution for each numerical column
for col in numerical_cols:
    hist_frequencies(dataset, col, 10)
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Histogram with Densities and KDE line (kernel density estimate)

# %% [markdown]
# The Kernel Density Estimator provides a smooth curve that represents the distribution of data points based on estimating the probability density function of a random variable:
# $$ \hat{f}(x; h) = \frac{1}{n} \sum_{i=1}^{n} K_h(x - X_i) $$
# Where:
# * n: total number of data points
# * $X_i$: observed data points
# * $K_h$: kernel function scaled by the bandwidth h
# $$ K_h(z) = \frac{1}{h} K\left(\frac{z}{h}\right) $$
# * $K$: Gaussian Kernel
# $$ K(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{x^2}{2}} $$

# %%
# function to plot distribution for 1 numerical column
def hist_density(data, column, bins):
    sbn.histplot(data[column], color = "blue", bins = bins, kde = False, stat = "density", alpha = 0.5)
    sbn.kdeplot(data[column], color = "red", linewidth = 2)
    plt.xlabel(column)
    plt.ylabel("Density")
    plt.title("Histogram and KDE for " + column)    
    plt.show()

# %%
# plot the distribution for each numerical column
for col in numerical_cols:
    hist_density(dataset, col, 10)
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Box Plot

# %%
# function to make boxplot
def statistics_nvar(data, numerical_cols):
    # calculate the nrows and ncols for plots
    ncol_plots = 3
    nrow_plots = (len(numerical_cols) + ncol_plots - 1) // ncol_plots
    # create the subplots for specific row and column
    fig, axs = plt.subplots(nrow_plots, ncol_plots, figsize = (16, 4 * nrow_plots))
    axs = axs.flatten()
    # create boxplots for each numerical column
    for i, col in enumerate(numerical_cols):
        sbn.boxplot(data[col], ax = axs[i])
        axs[i].set_title("Box plot for " + col)
    plt.tight_layout()
    plt.show()

# %%
# boxplot for each numerical column
statistics_nvar(dataset, numerical_cols)

# %% [markdown]
# Statistical metrics

# %%
# statistical information about numerical variables
dataset[numerical_cols].describe()
# Out:
#                 GP           GS         MINS            G            A  \
# count  8238.000000  8238.000000  8238.000000  8238.000000  8238.000000
# mean     19.031925    15.071012  1353.898155     2.166788     2.193736
# std       8.814166     9.610425   827.701927     3.409505     2.867026
# min       1.000000     0.000000     1.000000     0.000000     0.000000
# 25%      12.000000     7.000000   628.000000     0.000000     0.000000
# 50%      20.000000    15.000000  1334.500000     1.000000     1.000000
# 75%      26.000000    23.000000  2059.000000     3.000000     3.000000
# max      35.000000    34.000000  3060.000000    34.000000    26.000000
#
#               SHTS          SOG          GWG
# count  8238.000000  8238.000000  8238.000000
# mean     19.667395     7.796917     0.564215
# std      21.390956     9.706068     1.091845
# min       0.000000     0.000000     0.000000
# 25%       5.000000     1.000000     0.000000
# 50%      12.000000     4.000000     0.000000
# 75%      28.000000    11.000000     1.000000
# max     181.000000    76.000000    11.000000

# %% [markdown]
# Correlation Analysis

# %% [markdown]
# The correlation between 2 variables quantify the linear relationship between the variables X and Y:
# $$ r = \frac{\text{Cov}(X, Y)}{\sigma_X \sigma_Y} $$
# Where:
#
# $r$: pearson correlation coefficient
# $Cov(x, y)$: covariance between variables X and Y. It measures how much the two variables change together.
# $\sigma_X, \sigma_Y$: standard deviations for variables X and Y.
#
# Formula of Covariance:
# $$ \text{Cov}(X, Y) = \frac{1}{n-1} \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y}) $$
# Formula for standard deviation for X:
# $$ \sigma_X = \sqrt{\frac{1}{n-1} \sum_{i=1}^{n} (X_i - \bar{X})^2} $$
# Formula for standard deviation for Y:
# $$ \sigma_Y = \sqrt{\frac{1}{n-1} \sum_{i=1}^{n} (Y_i - \bar{Y})^2} $$

# %%
# function to plot correlation between numerical variables
def plot_correlation(data, cols):
    corr = data[cols].corr()
    plt.matshow(corr, cmap = "coolwarm")
    plt.xticks(range(len(cols)), cols, rotation = 90)
    plt.yticks(range(len(cols)), cols)

    # add the correlation values in each cell
    for (i, j), val in np.ndenumerate(corr):
        plt.text(j, i, f"{val:.1f}", ha='center', va='center', color='black')
    plt.title("Correlation Analysis")
    plt.colorbar()    
    plt.show()

# %%
plot_correlation(dataset, numerical_cols)

# %% [markdown]
# Implications of Low Correlation
#
# - **Independence of Features**:
# Low correlation suggests that the features are likely independent of each other.
# This can be beneficial because independent features provide unique information to the model, which can improve its performance.
# - **Feature Redundancy**:
# When features are not correlated, it reduces the risk of redundancy.
# Including redundant features (highly correlated) can lead to issues like multicollinearity, making it difficult to interpret the model and possibly degrading its performance.
# - **Model Complexity**:
# Low correlation may indicate that the model needs to learn more complex relationships to make accurate predictions.
# If features do not provide overlapping information, the model may require more sophisticated techniques (like polynomial regression or interaction terms) to capture the underlying patterns.
# - **Feature Selection**:
# In some cases, low-correlation features might be candidates for removal if they do not contribute significantly to the predictive power of the model.

# %% [markdown]
# **Outliers detection using Z-Score**
# The Z-score is the number of standard deviations from the mean that a data point is.
# The formula for the Z-score is:
# $$ Z = \frac{x - \mu}{\sigma} $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# function to plot gaussian kernel
def plot_gaussian_kernel(mean=0, std_dev=1, num_points=1000):    
    # Generate x values
    x = np.linspace(mean - 4 * std_dev, mean + 4 * std_dev, num_points)
    
    # Calculate the Gaussian kernel values
    gaussian_kernel = (1 / (np.sqrt(2 * np.pi) * std_dev)) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(x, gaussian_kernel, color='blue', label=f'Gaussian Kernel\nMean = {mean}, Std Dev = {std_dev}')
    plt.title('Gaussian Kernel')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.axvline(mean, color='red', linestyle='--', label='Mean')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# standard gaussian kernel
plot_gaussian_kernel(mean=0, std_dev=1)

# %%
from scipy.stats import norm

# Calculate the percentile for a specific Z-score
def call_percentile(z):
    percentile = float(round(norm.cdf(z) * 100, 3))
    return percentile

# %%
call_percentile(z = -2)
# Out:
# 2.275

# %%
from scipy import stats

# Function for outliers detection based on percentiles
def outliers_detection(dataset, col, lower_percentile=2.275, upper_percentile=97.725):
    # Calculate the percentiles
    lower_bound = dataset[col].quantile(lower_percentile / 100)
    upper_bound = dataset[col].quantile(upper_percentile / 100)
    
    # Filter out the outliers
    outliers = dataset[(dataset[col] < lower_bound) | (dataset[col] > upper_bound)]
    
    return outliers

# %%
outliers_detection(dataset, "GP").head()
# Out:
#                Player Club POS  GP  GS  MINS  G  A  SHTS  SOG  ...  RdA  \
# 110      Yari Allnutt  KC    F   1   0    45  1  0     1    1  ...    0
# 190  Louis Ken-Kwofie  MET   M   1   1    90  0  0     1    0  ...    0
# 328      Yari Allnutt  KC    F   1   0    45  1  0     1    1  ...    0
# 408  Louis Ken-Kwofie  MET   M   1   1    90  0  0     1    0  ...    0
# 579  Gerson Echeverry  MET   F   1   1    74  0  1     1    0  ...    0
#
#     A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season
# 110    0.00   1   0    0   0   0  100.0  1996     reg
# 190    0.00   0   3    1   0   0    0.0  1996     reg
# 328    0.00   1   0    0   0   0  100.0  1996     reg
# 408    0.00   0   3    1   0   0    0.0  1996     reg
# 579    1.22   2   1    1   0   0    0.0  1997     reg
#
# [5 rows x 28 columns]

# %%
# cycle to check the number of outliers in each numerical column
for col in numerical_cols:
    print("\n*** Outliers detection in " + col + " ***")
    lst_outliers = outliers_detection(dataset, col)
    print(f"#samples outlier to distribution = {len(lst_outliers)}")
    print(f"%outliers = {round(100* len(lst_outliers)/len(dataset), 2)} %")
# Out:
# *** Outliers detection in GP ***
# #samples outlier to distribution = 194
# %outliers = 2.35 %
#
# *** Outliers detection in GS ***
# #samples outlier to distribution = 102
# %outliers = 1.24 %
#
# *** Outliers detection in MINS ***
# #samples outlier to distribution = 374
# %outliers = 4.54 %
#
# *** Outliers detection in G ***
# #samples outlier to distribution = 178
# %outliers = 2.16 %
#
# *** Outliers detection in A ***
# #samples outlier to distribution = 142
# %outliers = 1.72 %
#
# *** Outliers detection in SHTS ***
# #samples outlier to distribution = 185
# %outliers = 2.25 %
#
# *** Outliers detection in SOG ***
# #samples outlier to distribution = 183
# %outliers = 2.22 %
#
# *** Outliers detection in GWG ***
# #samples outlier to distribution = 135
# %outliers = 1.64 %

# %% [markdown]
# #### Categorical Variables

# %%
# list of categorical variables
categorical_vars = list(set(dataset.columns) - set(numerical_cols))
categorical_vars
# Out:
# ['HmG',
#  'POS',
#  'RC',
#  'A/90min',
#  'YC',
#  'SOG%',
#  'SC%',
#  'Player',
#  'RdG',
#  'Year',
#  'FC',
#  'FS',
#  'PKG/A',
#  'Season',
#  'GWA',
#  'HmA',
#  'G/90min',
#  'RdA',
#  'Club',
#  'OFF']

# %% [markdown]
# Count instances for each categorical column

# %%
# cycle to calculate number of instances in each categorical column
for col in categorical_vars:
    print("\n***** " + col + " ******")
    print(dataset[col].value_counts())
# Out:
# ***** HmG ******
# HmG
# 0     4385
# 1     1625
# 2      817
# 3      456
# 4      316
# 5      192
# 6      136
# 7      101
# 8       74
# 9       36
# 10      32
# 11      16
# 13      16
# 15       9
# 12       9
# 14       7
# 16       3
# 19       3
# 18       2
# 20       1
# 17       1
# 22       1
# Name: count, dtype: int64
#
# ***** POS ******
# POS
# M      3143
# D      2771
# F      1860
# M-F     198
# D-M     125
# M-D      82
# F-M      59
# Name: count, dtype: int64
#
# ***** RC ******
# RC
# 0    6933
# 1    1165
# 2     127
# 3      13
# Name: count, dtype: int64
#
# ***** A/90min ******
# A/90min
# 0.00    2814
# 0.04     267
# 0.07     241
# 0.10     223
# 0.08     214
#         ...
# 1.68       1
# 1.06       1
# 1.08       1
# 1.22       1
# 1.73       1
# Name: count, Length: 110, dtype: int64
#
# ***** YC ******
# YC
# 0     1845
# 1     1604
# 2     1282
# 3     1066
# 4      836
# 5      622
# 6      455
# 7      252
# 8      144
# 9       72
# 10      29
# 11      20
# 13       5
# 12       4
# 14       2
# Name: count, dtype: int64
#
# ***** SOG% ******
# SOG%
# 0.00      1087
# 50.00      654
# 33.33      545
# 25.00      330
# 100.00     279
#           ...
# 61.82        1
# 59.57        1
# 31.96        1
# 30.16        1
# 27.45        1
# Name: count, Length: 725, dtype: int64
#
# ***** SC% ******
# SC%
# 0.0     3421
# 16.7     218
# 14.3     199
# 20.0     196
# 12.5     184
#         ...
# 1.9        1
# 24.6       1
# 23.6       1
# 71.4       1
# 58.3       1
# Name: count, Length: 283, dtype: int64
#
# ***** Player ******
# Player
# Kyle Beckerman     20
# Chad Marshall      16
# Jaime Moreno       16
# Ramiro Corrales    16
# Drew Moor          16
#                    ..
# Federico Puppo      1
# Steven Smith        1
# Miguel Aceval       1
# Nemanja Vukovic     1
# Nicolas Figal       1
# Name: count, Length: 2529, dtype: int64
#
# ***** RdG ******
# RdG
# 0     4899
# 1     1671
# 2      730
# 3      403
# 4      204
# 5      121
# 6       84
# 7       45
# 8       34
# 9       26
# 10      14
# 11       4
# 14       1
# 15       1
# 16       1
# Name: count, dtype: int64
#
# ***** Year ******
# Year
# 2020    540
# 2019    525
# 2018    502
# 2017    470
# 2015    437
# 2013    431
# 2016    416
# 2014    416
# 2012    408
# 2011    392
# 1996    384
# 2010    328
# 2009    301
# 2008    294
# 2007    257
# 2005    244
# 2006    240
# 1999    228
# 2000    227
# 1998    227
# 2001    214
# 2004    191
# 2003    189
# 2002    189
# 1997    188
# Name: count, dtype: int64
#
# ***** FC ******
# FC
# 4     275
# 3     257
# 6     251
# 10    240
# 5     239
#      ...
# 80      2
# 78      2
# 81      1
# 72      1
# 86      1
# Name: count, Length: 83, dtype: int64
#
# ***** FS ******
# FS
# 2      338
# 3      327
# 6      322
# 4      314
# 1      305
#       ...
# 112      1
# 101      1
# 95       1
# 110      1
# 108      1
# Name: count, Length: 100, dtype: int64
#
# ***** PKG/A ******
# PKG/A
# 0/0     7348
# 1/1      286
# 0/1      167
# 2/2       92
# 3/3       62
# 1/2       59
# 2/3       49
# 4/4       36
# 3/4       29
# 4/5       25
# 5/5       15
# 5/6       13
# 1/3       10
# 3/5       10
# 7/8        6
# 6/6        6
# 0/2        5
# 2/4        5
# 4/6        3
# 1/4        2
# 6/7        2
# 9/9        1
# 5/7        1
# 6/8        1
# 5/8        1
# 8/9        1
# 9/11       1
# 4/7        1
# 4/8        1
# Name: count, dtype: int64
#
# ***** Season ******
# Season
# reg    8238
# Name: count, dtype: int64
#
# ***** GWA ******
# GWA
# 0    5340
# 1    1754
# 2     669
# 3     284
# 4     107
# 5      58
# 6      15
# 7       8
# 8       3
# Name: count, dtype: int64
#
# ***** HmA ******
# HmA
# 0     3819
# 1     1916
# 2     1024
# 3      571
# 4      360
# 5      197
# 6      131
# 7       87
# 8       42
# 9       41
# 10      25
# 13       9
# 11       9
# 12       5
# 15       1
# 16       1
# Name: count, dtype: int64
#
# ***** G/90min ******
# G/90min
# 0.00    3421
# 0.04     287
# 0.07     207
# 0.05     203
# 0.08     190
#         ...
# 1.91       1
# 1.80       1
# 1.23       1
# 2.31       1
# 1.76       1
# Name: count, Length: 141, dtype: int64
#
# ***** RdA ******
# RdA
# 0     4553
# 1     1908
# 2      858
# 3      450
# 4      231
# 5      123
# 6       56
# 7       31
# 8       18
# 9        4
# 11       2
# 10       2
# 12       1
# 13       1
# Name: count, dtype: int64
#
# ***** Club ******
# Club
# COL     561
# CLB     535
# CHI     507
# DAL     500
# LA      431
# DC      421
# KC      362
# NE      351
# RSL     342
# SJ      334
# HOU     317
# TOR     299
# SEA     244
# MET     222
# CHV     216
# PHI     199
# POR     193
# MTL     185
# VAN     181
# MIA     171
# NY      170
# DC      131
# ORL     122
# MIN     118
# NE      116
# NYC     108
# TB      108
# SKC     106
# SJ       98
# NSH      96
# LA       91
# ATL      87
# LAFC     73
# CIN      72
# RBNY     62
# NY       30
# NYR      28
# LFC      16
# HON       9
# USA       5
# PAN       5
# CAN       4
# HAI       3
# ECU       2
# ROC       2
# CIV       2
# SLV       2
# JAM       1
# Name: count, dtype: int64
#
# ***** OFF ******
# OFF
# 0     3219
# 1     1442
# 2      769
# 3      514
# 4      353
# 5      266
# 6      191
# 7      156
# 8      149
# 10     122
# 9      118
# 11      92
# 12      87
# 13      66
# 16      65
# 15      61
# 14      59
# 17      45
# 19      43
# 18      41
# 23      39
# 21      36
# 20      30
# 22      26
# 25      23
# 24      23
# 27      21
# 35      15
# 32      15
# 33      14
# 28      14
# 30      13
# 26      10
# 31      10
# 37      10
# 34      10
# 29       9
# 36       8
# 41       8
# 40       7
# 38       6
# 44       5
# 43       4
# 39       4
# 42       3
# 50       2
# 45       2
# 70       2
# 55       2
# 49       1
# 82       1
# 56       1
# 54       1
# 46       1
# 48       1
# 78       1
# 47       1
# 51       1
# Name: count, dtype: int64

# %% [markdown]
# Bar chart - Analysis of absolute frequencies

# %%
# function to plot distribution for 1 categorical column
def plot_count_categories(dataset, col):
    results = dataset[col].value_counts()
    sbn.barplot(x = results.values.tolist(), y = results.index.tolist(), orient = "y")
    plt.title("Statistical analysis by " + col)
    plt.show()

# %%
# cycle to plot distribution for each categorical column
for col in categorical_vars:
    plot_count_categories(dataset, col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 3
#       1 # cycle to plot distribution for each categorical column
#       2 for col in categorical_vars:
# ----> 3     plot_count_categories(dataset, col)
#
# Cell In[135], line 4, in plot_count_categories(dataset, col)
#       2 def plot_count_categories(dataset, col):
#       3     results = dataset[col].value_counts()
# ----> 4     sbn.barplot(x = results.values.tolist(), y = results.index.tolist(), orient = "y")
#       5     plt.title("Statistical analysis by " + col)
#       6     plt.show()
#
# File D:\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File D:\anaconda3\Lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File D:\anaconda3\Lib\site-packages\seaborn\categorical.py:544, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     541         raise ValueError(err)
#     543 # Figure out the plotting orientation
# --> 544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#     548 # Option 2a:
#     549 # We are plotting a single set of data
#     550 # ------------------------------------
#     551 if x is None or y is None:
#     552
#     553     # Determine where the data are
#
# File D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1619, in infer_orient(x, y, orient, require_numeric)
#    1614 elif orient is not None:
#    1615     err = (
#    1616         "`orient` must start with 'v' or 'h' or be None, "
#    1617         f"but `{repr(orient)}` was passed."
#    1618     )
# -> 1619     raise ValueError(err)
#    1621 elif x_type != "categorical" and y_type == "categorical":
#    1622     return "h"
#
# ValueError: `orient` must start with 'v' or 'h' or be None, but `'y'` was passed.

# %% [markdown]
# Pie Chart - Analysis of relative frequencies

# %%
def plot_piechart(dataset, col):
    # count the #samples for each categogy
    results = dataset[col].value_counts()
    # calculate the relative frequencies
    total_samples = results.sum()
    rel_freq = results/total_samples
    sbn.set_style("whitegrid")
    plt.figure(figsize=(6,6))
    plt.pie(rel_freq.values.tolist(), labels = rel_freq.index.tolist(), autopct='%1.1f%%')
    plt.title("Relative frequency analysis by " + col)
    plt.show()

# %%
# cycle to plot relative distributions for each categorical column
for col in categorical_vars:
    plot_piechart(dataset, col)

# %% [markdown]
# Statistical Analysis for subgroups

# %%
# create groups organized by sex and income
group_pos_income = dataset.groupby(["GP", "POS"]).size().reset_index(name = "samples")
print(group_pos_income)
# Out:
#      GP  POS  samples
# 0     1    D       27
# 1     1  D-M        1
# 2     1    F       42
# 3     1  F-M        1
# 4     1    M       31
# ..   ..  ...      ...
# 219  34    D       24
# 220  34    F       19
# 221  34  F-M        1
# 222  34    M       41
# 223  35    M        1
#
# [224 rows x 3 columns]

# %%
def plot_absfreq_groups(group, g1, g2):
    sbn.barplot(data = group, x = g1, y = "samples", hue = g2, palette = "pastel")
    plt.xlabel('POS')
    plt.ylabel('Absolute Frequencies')
    plt.title('Bar Chart of Absolute Frequencies by POS and GP')
    plt.tight_layout()
    plt.show()

# %%
plot_absfreq_groups(group_pos_income, "GP", "POS")

# %%
def plot_relfreq_groups(group, g1, g2):
    labels = group[g1] + " with salary " + group[g2]
    sizes = group["samples"]
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')
    plt.title('Pie Chart of Relative Frequencies by POS and GP')
    plt.show()

# %%
plot_relfreq_groups(group_pos_income, "GP", "POS")
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 plot_relfreq_groups(group_pos_income, "GP", "POS")
#
# Cell In[146], line 2, in plot_relfreq_groups(group, g1, g2)
#       1 def plot_relfreq_groups(group, g1, g2):
# ----> 2     labels = group[g1] + " with salary " + group[g2]
#       3     sizes = group["samples"]
#       4     plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\series.py:5819, in Series._arith_method(self, other, op)
#    5817 def _arith_method(self, other, op):
#    5818     self, other = self._align_for_op(other)
# -> 5819     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File D:\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     217     func = partial(expressions.evaluate, op)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('int64'), dtype('<U13')) -> None
